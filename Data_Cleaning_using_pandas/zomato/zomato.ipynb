# %%
import pandas as pd

# %%
df=pd.read_csv('zomato.csv')

# %%
df.shape
# Out:
# (51717, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head(6)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
# 5  https://www.zomato.com/bangalore/timepass-dinn...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
# 5  37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar...        Timepass Dinner
#
# ...

# %%
df.drop(columns=['url'],inplace=True)

# %%
df.drop(columns=['address','reviews_list','menu_item','listed_in(type)','listed_in(city)'],inplace=True)

# %%
df.head(5)
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#                               phone      location            rest_type  \
# 0    080 42297555\r\n+91 9743772233  Banashankari        Casual Dining
# 1                      080 41714161  Banashankari        Casual Dining
# 2                    +91 9663487993  Banashankari  Cafe, Casual Dining
# 3                    +91 9620009302  Banashankari          Quick Bites
# 4  +91 8026612447\r\n+91 9901210005  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# ...

# %%
df['rate']=df['rate'].str.split('/').str[0]

# %%
df['rate'].head(6)
# Out:
# 0    4.1
# 1    4.1
# 2    3.8
# 3    3.7
# 4    3.8
# 5    3.8
# Name: rate, dtype: object

# %%
df['phone'].isnull().sum()
# Out:
# np.int64(1208)

# %%
df['phone'].head(20)
# Out:
# 0       080 42297555\r\n+91 9743772233
# 1                         080 41714161
# 2                       +91 9663487993
# 3                       +91 9620009302
# 4     +91 8026612447\r\n+91 9901210005
# 5     +91 9980040002\r\n+91 9980063005
# 6       +91 9731716688\r\n080 26740366
# 7         080 48653961\r\n080 48655715
# 8     +91 8884135549\r\n+91 9449449316
# 9     +91 9945230807\r\n+91 9743804471
# 10      080 26724489\r\n+91 7406048982
# 11                      +91 9742166777
# 12                      +91 9731644212
# 13                        080 49577715
# 14                      +91 9663487993
# 15      080 26768182\r\n+91 9845704455
# 16    +91 9972988038\r\n+91 9900121238
# 17      080 26711554\r\n+91 9741406338
# 18                      +91 8884726600
# 19                      +91 9880594520
# Name: phone, dtype: object

# %%
# Clean \r\n and spaces
df['phone']=df['phone'].str.replace(r'\r\n',',',regex=True).str.strip()

# %%
# Extract digits only
df['phone']
# Out:
# 0          080 42297555,+91 9743772233
# 1                         080 41714161
# 2                       +91 9663487993
# 3                       +91 9620009302
# 4        +91 8026612447,+91 9901210005
#                      ...
# 51712                     080 40301477
# 51713                   +91 8197675843
# 51714                              NaN
# 51715                     080 49652769
# 51716                   +91 8071117272
# Name: phone, Length: 51717, dtype: object

# %%
df['phone'].head(20)
# Out:
# 0       080 42297555,+91 9743772233
# 1                      080 41714161
# 2                    +91 9663487993
# 3                    +91 9620009302
# 4     +91 8026612447,+91 9901210005
# 5     +91 9980040002,+91 9980063005
# 6       +91 9731716688,080 26740366
# 7         080 48653961,080 48655715
# 8     +91 8884135549,+91 9449449316
# 9     +91 9945230807,+91 9743804471
# 10      080 26724489,+91 7406048982
# 11                   +91 9742166777
# 12                   +91 9731644212
# 13                     080 49577715
# 14                   +91 9663487993
# 15      080 26768182,+91 9845704455
# 16    +91 9972988038,+91 9900121238
# 17      080 26711554,+91 9741406338
# 18                   +91 8884726600
# 19                   +91 9880594520
# Name: phone, dtype: object

# %%
# # Cleaning function
# def split_phone_numbers(phone_str):
#     if pd.isna(phone_str):
#         return pd.Series([None, None])  
    
#     # Split by comma
#     nums = [num.strip() for num in phone_str.split(",")]
    
#     landline = None
#     mobile = None
    
#     for num in nums:
#         digits = "".join(ch for ch in num if ch.isdigit())  # keep only digits
#         if digits.startswith("91") and len(digits) >= 12:  # mobile
#             mobile = "+{}".format(digits)
#         elif digits.startswith("080"):  # landline
#             landline = digits
#     return pd.Series([landline, mobile])

# %%
df.drop(columns=['phone'],inplace=True)

# %%
df.head(5)
# Out:
#                     name online_order book_table rate  votes      location  \
# 0                  Jalsa          Yes        Yes  4.1    775  Banashankari
# 1         Spice Elephant          Yes         No  4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No  3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No  3.7     88  Banashankari
# 4          Grand Village           No         No  3.8    166  Basavanagudi
#
#              rest_type                                         dish_liked  \
# 0        Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1        Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Cafe, Casual Dining  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3          Quick Bites                                        Masala Dosa
# 4        Casual Dining                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)
# ...

# %%
df['cuisines'].head(20)
# Out:
# 0                   North Indian, Mughlai, Chinese
# 1                      Chinese, North Indian, Thai
# 2                           Cafe, Mexican, Italian
# 3                       South Indian, North Indian
# 4                         North Indian, Rajasthani
# 5                                     North Indian
# 6      North Indian, South Indian, Andhra, Chinese
# 7                             Pizza, Cafe, Italian
# 8                       Cafe, Italian, Continental
# 9         Cafe, Mexican, Italian, Momos, Beverages
# 10                                            Cafe
# 11                      Cafe, Italian, Continental
# 12             Cafe, Chinese, Continental, Italian
# 13                               Cafe, Continental
# 14                          Cafe, Mexican, Italian
# 15                                            Cafe
# 16    Cafe, Fast Food, Continental, Chinese, Momos
# 17                          Chinese, Cafe, Italian
# ...

# %%
df['cuisines']=df['cuisines'].str.split(',')

# %%
df["cuisines"]
# Out:
# 0                [North Indian,  Mughlai,  Chinese]
# 1                   [Chinese,  North Indian,  Thai]
# 2                        [Cafe,  Mexican,  Italian]
# 3                     [South Indian,  North Indian]
# 4                       [North Indian,  Rajasthani]
#                             ...
# 51712                                 [Continental]
# 51713                                 [Finger Food]
# 51714                                 [Finger Food]
# 51715                                 [Finger Food]
# 51716    [Finger Food,  North Indian,  Continental]
# Name: cuisines, Length: 51717, dtype: object

# %%
df['cuisines'].fillna('North Indian',inplace=True)

# %%
df = df.explode("cuisines").reset_index(drop=True)

# %%
df['cuisines']
# Out:
# 0          North Indian
# 1               Mughlai
# 2               Chinese
# 3               Chinese
# 4          North Indian
#               ...
# 126859      Finger Food
# 126860      Finger Food
# 126861      Finger Food
# 126862     North Indian
# 126863      Continental
# Name: cuisines, Length: 126864, dtype: object

# %%
df
# Out:
#                                                      name online_order  \
# 0                                                   Jalsa          Yes
# 1                                                   Jalsa          Yes
# 2                                                   Jalsa          Yes
# 3                                          Spice Elephant          Yes
# 4                                          Spice Elephant          Yes
# ...                                                   ...          ...
# 126859  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 126860  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 126861                       The Nest - The Den Bengaluru           No
# 126862                       The Nest - The Den Bengaluru           No
# 126863                       The Nest - The Den Bengaluru           No
#
#        book_table  rate  votes                    location  \
# ...

# %%
df['dish_liked']=df['dish_liked'].str.split(',')

# %%
df['dish_liked']
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#             ...
# 126859    [Biryani]
# 126860          NaN
# 126861    [Biryani]
# 126862    [Biryani]
# 126863    [Biryani]
# Name: dish_liked, Length: 126864, dtype: object

# %%
df['dish_liked'].mode()
# Out:
# 0    [Biryani]
# Name: dish_liked, dtype: object

# %%
df['dish_liked'].fillna('Biryani',inplace=True)

# %%
df=df.explode("dish_liked").reset_index(drop=True)

# %%
df
# Out:
#                                                      name online_order  \
# 0                                                   Jalsa          Yes
# 1                                                   Jalsa          Yes
# 2                                                   Jalsa          Yes
# 3                                          Spice Elephant          Yes
# 4                                          Spice Elephant          Yes
# ...                                                   ...          ...
# 126859  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 126860  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 126861                       The Nest - The Den Bengaluru           No
# 126862                       The Nest - The Den Bengaluru           No
# 126863                       The Nest - The Den Bengaluru           No
#
#        book_table  rate  votes                    location  \
# ...

# %%
df['dish_liked']=df['dish_liked'].str.split('[').str[0]

# %%
df['dish_liked'].fillna('Biryani',inplace=True)

# %%
df.head(5)
# Out:
#              name online_order book_table rate  votes      location  \
# 0           Jalsa          Yes        Yes  4.1    775  Banashankari
# 1           Jalsa          Yes        Yes  4.1    775  Banashankari
# 2           Jalsa          Yes        Yes  4.1    775  Banashankari
# 3  Spice Elephant          Yes         No  4.1    787  Banashankari
# 4  Spice Elephant          Yes         No  4.1    787  Banashankari
#
#        rest_type dish_liked       cuisines approx_cost(for two people)
# 0  Casual Dining    Biryani   North Indian                         800
# 1  Casual Dining    Biryani        Mughlai                         800
# 2  Casual Dining    Biryani        Chinese                         800
# 3  Casual Dining    Biryani        Chinese                         800
# 4  Casual Dining    Biryani   North Indian                         800

# %%
df['rest_type']=df['rest_type'].str.split(',')

# %%
df['rest_type'].isnull().sum()
# Out:
# np.int64(522)

# %%
df['rest_type'].mode()
# Out:
# 0    [Quick Bites]
# Name: rest_type, dtype: object

# %%
df['rest_type']=df['rest_type'].fillna('Quick Bites')

# %%
df['rest_type'].isnull().sum()
# Out:
# np.int64(0)

# %%
df=df.explode('rest_type').reset_index(drop=True)

# %%
df.head(10)
# Out:
#               name online_order book_table rate  votes      location  \
# 0            Jalsa          Yes        Yes  4.1    775  Banashankari
# 1            Jalsa          Yes        Yes  4.1    775  Banashankari
# 2            Jalsa          Yes        Yes  4.1    775  Banashankari
# 3   Spice Elephant          Yes         No  4.1    787  Banashankari
# 4   Spice Elephant          Yes         No  4.1    787  Banashankari
# 5   Spice Elephant          Yes         No  4.1    787  Banashankari
# 6  San Churro Cafe          Yes         No  3.8    918  Banashankari
# 7  San Churro Cafe          Yes         No  3.8    918  Banashankari
# 8  San Churro Cafe          Yes         No  3.8    918  Banashankari
# 9  San Churro Cafe          Yes         No  3.8    918  Banashankari
#
#         rest_type dish_liked       cuisines approx_cost(for two people)
# 0   Casual Dining    Biryani   North Indian                         800
# ...

# %%
df=df.rename(
    columns={
        'name':'Restaurant_name',
        'rest_type':'Restaurant_type',
        'approx_cost(for two people)':'Cost_of_two_people',
        'rate':'rating'
    }
)

# %%
df.columns
# Out:
# Index(['Restaurant_name', 'online_order', 'book_table', 'rating', 'votes',
#        'location', 'Restaurant_type', 'dish_liked', 'cuisines',
#        'Cost_of_two_people'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Restaurant_name       object
# online_order          object
# book_table            object
# rate                  object
# votes                  int64
# location              object
# Restaurant_type       object
# dish_liked            object
# cuisines              object
# Cost_of_two_people    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Restaurant_name           0
# online_order              0
# book_table                0
# rating                16974
# votes                     0
# location                 21
# Restaurant_type           0
# dish_liked                0
# cuisines                  0
# Cost_of_two_people     1019
# dtype: int64

# %%
df['rating']=df['rating'].str.strip()

# %%
df["rating"] = pd.to_numeric(df["rating"], errors="coerce")


df["rating"] = df["rating"].fillna(df["rating"].median())

# %%
df['location'].mode()
# Out:
# 0    BTM
# Name: location, dtype: object

# %%
df['location'].fillna('BTM',inplace=True)

# %%
df['Cost_of_two_people']=pd.to_numeric(df['Cost_of_two_people'],errors='coerce')
df['Cost_of_two_people']=df['Cost_of_two_people'].fillna(df['Cost_of_two_people'].median())

# %%
df.dtypes
# Out:
# Restaurant_name        object
# online_order           object
# book_table             object
# rating                float64
# votes                   int64
# location               object
# Restaurant_type        object
# dish_liked             object
# cuisines               object
# Cost_of_two_people    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Restaurant_name       0
# online_order          0
# book_table            0
# rating                0
# votes                 0
# location              0
# Restaurant_type       0
# dish_liked            0
# cuisines              0
# Cost_of_two_people    0
# dtype: int64

# %%
df.head(5)
# Out:
#   Restaurant_name online_order book_table  rating  votes      location  \
# 0           Jalsa          Yes        Yes     4.1    775  Banashankari
# 1           Jalsa          Yes        Yes     4.1    775  Banashankari
# 2           Jalsa          Yes        Yes     4.1    775  Banashankari
# 3  Spice Elephant          Yes         No     4.1    787  Banashankari
# 4  Spice Elephant          Yes         No     4.1    787  Banashankari
#
#   Restaurant_type dish_liked       cuisines  Cost_of_two_people
# 0   Casual Dining    Biryani   North Indian               800.0
# 1   Casual Dining    Biryani        Mughlai               800.0
# 2   Casual Dining    Biryani        Chinese               800.0
# 3   Casual Dining    Biryani        Chinese               800.0
# 4   Casual Dining    Biryani   North Indian               800.0
